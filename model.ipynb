# %% [markdown]
# # This is reconstruction of LeNet 5 in TensorFlow
# This is meant solely as a learning exercise and is neither the fastest nor the best implementation around.

# %% [markdown]
# # Imports

# %%
from tensorflow.keras import Sequential, layers, Model
from tensorflow.keras.datasets import mnist, cifar10
from tensorflow import pad, expand_dims, cast, float32, int32
from tensorflow.config import list_physical_devices
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
import numpy as np

# %% [markdown]
# # Base Model
# Implemented according to the exact architecture.

# %%
class LeNet(Model):
    def __init__(self):
        super().__init__()
        self.conv1 = layers.Conv2D(filters=6, kernel_size=(5, 5), activation='tanh', input_shape=(32, 32, 3))
        self.pool2 = layers.AveragePooling2D((2, 2), strides=2)
        self.conv3 = layers.Conv2D(filters=16, kernel_size=(5, 5), activation='tanh')
        self.pool4 = layers.AveragePooling2D((2, 2), strides=2)
        self.conv5 = layers.Conv2D(filters=120, kernel_size=(5, 5), activation='tanh')
        self.flat6 = layers.Flatten()
        self.dense7 = layers.Dense(units=84, activation='tanh')
        self.dense8 = layers.Dense(units=10, activation='softmax')

    def call(self, x):
        x = self.conv1(x)
        x = self.pool2(x)
        x = self.conv3(x)
        x = self.pool4(x)
        x = self.conv5(x)
        x = self.flat6(x)
        x = self.dense7(x)
        x = self.dense8(x)

        return x

# %% [markdown]
# # Testing on MNIST

# %%
model = LeNet()
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "le_net_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_13 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_9             │ ?                      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_10            │ ?                      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ...

# %% [markdown]
# ## Loading the Dataset

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
padded_x_train = pad(x_train, [[0, 0], [2, 2], [2, 2]], mode='constant', constant_values=0)
padded_x_test = pad(x_test, [[0, 0], [2, 2], [2, 2]], mode='constant', constant_values=0)

padded_x_train = expand_dims(padded_x_train, -1)
padded_x_test = expand_dims(padded_x_test, -1)

padded_x_train.shape
# Out:
# TensorShape([60000, 32, 32, 1])

# %% [markdown]
# ## Normalizing

# %%
padded_x_train = cast(padded_x_train, float32) / 255.0
padded_x_test = cast(padded_x_test, float32) / 255.0

# %% [markdown]
# ## Training

# %%
model.fit(
    padded_x_train,
    y_train,
    epochs=10,
)
# Out:
# Epoch 1/10
# 2026-04-29 22:06:32.181955: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 31s 14ms/step - accuracy: 0.9339 - loss: 0.2238
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.9740 - loss: 0.0836
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 28s 15ms/step - accuracy: 0.9827 - loss: 0.0559
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.9862 - loss: 0.0435
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 26s 14ms/step - accuracy: 0.9894 - loss: 0.0341
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9912 - loss: 0.0280
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.9920 - loss: 0.0243
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 27s 14ms/step - accuracy: 0.9930 - loss: 0.0216
# Epoch 9/10
# ...

# %% [markdown]
# ## Testing

# %%
y_pred = model.predict(padded_x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_pred_classes = y_pred.argmax(axis=1)

# %%
print('MSE:', mean_squared_error(y_test, y_pred_classes))
print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred_classes)))
print('R2 Score:', r2_score(y_test, y_pred_classes))
print('Accuracy:', accuracy_score(y_test, y_pred_classes))
# Out:
# MSE: 0.276
# RMSE: 0.5253570214625479
# R2 Score: 0.9670848498332855
# Accuracy: 0.9861

# %% [markdown]
# # Testing on CIFAR-10

# %%
model2 = LeNet()
model2.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model2.summary()
# Out:
# /Users/hamdan/PycharmProjects/LeNet/.venv/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-04-29 22:43:32.450279: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2026-04-29 22:43:32.450341: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2026-04-29 22:43:32.450353: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2026-04-29 22:43:32.450764: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %% [markdown]
# ## Loading the Dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train = y_train.squeeze()
y_test = y_test.squeeze()

y_train = cast(y_train, int32)
y_test = cast(y_test, int32)

y_train.shape
# Out:
# TensorShape([50000])

# %% [markdown]
# ## Normalizing

# %%
x_train = cast(x_train, float32) / 255.0
x_test = cast(x_test, float32) / 255.0

# %% [markdown]
# ## Training

# %%
print(x_train.shape, x_train.dtype)
print(y_train.shape, y_train.dtype)
# Out:
# (50000, 32, 32, 3) <dtype: 'float32'>
# (50000,) <dtype: 'int32'>

# %%
model2.fit(
    x_train,
    y_train,
    epochs=10
)
# Out:
# Epoch 1/10
# 2026-04-29 22:43:47.648699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 29s 18ms/step - accuracy: 0.3652 - loss: 1.7839
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 28s 18ms/step - accuracy: 0.4490 - loss: 1.5571
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 26s 17ms/step - accuracy: 0.4940 - loss: 1.4288
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 31s 20ms/step - accuracy: 0.5255 - loss: 1.3411
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.5460 - loss: 1.2792
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.5651 - loss: 1.2244
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.5822 - loss: 1.1810
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.5953 - loss: 1.1379
# Epoch 9/10
# ...
